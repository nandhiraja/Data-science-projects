# %% [markdown]
# # **Welcome to the NOTEBOOK **
#
#
# ## **About :**
# ### This dataset is about the sales in the online sales platform  there are many products were selling.
# ### from that data we going to perform some EDA ,Analysis and data modeling.

# %% [markdown]
# .

# %% [markdown]
# <div style="background-color: #fc4e8e; padding: 20px; border : 2px solid ;border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: BLACK; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 1px 2px #000000;">[......... EXPLORATORY DATA ANALYSIS..........]</h1>
# </div>

# %%
# import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data set

data = pd.read_csv("/kaggle/input/online-shopping-dataset/file.csv")
data.head()
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# ...

# %%
# see number of rows and columns

data.shape
# Out:
# (52955, 21)

# %%
data.nunique()
# Out:
# Unnamed: 0             52955
# CustomerID              1468
# Gender                     2
# Location                   5
# Tenure_Months             49
# Transaction_ID         25061
# Transaction_Date         365
# Product_SKU             1145
# Product_Description      404
# Product_Category          21
# Quantity                 151
# Avg_Price                546
# Delivery_Charges         267
# Coupon_Status              3
# GST                        4
# Date                     365
# Offline_Spend             11
# Online_Spend             365
# Month                     12
# Coupon_Code               48
# Discount_pct               3
# dtype: int64

# %%
# To check the describtion of the data

data.describe()
# Out:
#          Unnamed: 0   CustomerID  Tenure_Months  Transaction_ID      Quantity  \
# count  52955.000000  52924.00000   52924.000000    52924.000000  52924.000000
# mean   26477.000000  15346.70981      26.127995    32409.825675      4.497638
# std    15286.936089   1766.55602      13.478285     8648.668977     20.104711
# min        0.000000  12346.00000       2.000000    16679.000000      1.000000
# 25%    13238.500000  13869.00000      15.000000    25384.000000      1.000000
# 50%    26477.000000  15311.00000      27.000000    32625.500000      1.000000
# 75%    39715.500000  16996.25000      37.000000    39126.250000      2.000000
# max    52954.000000  18283.00000      50.000000    48497.000000    900.000000
#
#           Avg_Price  Delivery_Charges           GST  Offline_Spend  \
# count  52924.000000      52924.000000  52924.000000   52924.000000
# mean      52.237646         10.517630      0.137462    2830.914141
# ...

# %%
# see quick info

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52955 non-null  int64
#  1   CustomerID           52924 non-null  float64
#  2   Gender               52924 non-null  object
#  3   Location             52924 non-null  object
#  4   Tenure_Months        52924 non-null  float64
#  5   Transaction_ID       52924 non-null  float64
#  6   Transaction_Date     52924 non-null  object
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52955 non-null  object
#  10  Quantity             52924 non-null  float64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Coupon_Status        52924 non-null  object
#  14  GST                  52924 non-null  float64
# ...

# %%
# check missing values

data.isnull().sum()
# Out:
# Unnamed: 0               0
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Online_Spend            31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %%
# remove the null value rows

data = data.dropna()

# %%
# remove the unnecessary columns 

data = data.drop(columns=["Coupon_Code","Discount_pct","Unnamed: 0","CustomerID","Transaction_ID","Product_SKU","Transaction_Date"] ,axis=1)

# %%
data.nunique()
# Out:
# Gender                   2
# Location                 5
# Tenure_Months           49
# Product_Description    395
# Product_Category        16
# Quantity               151
# Avg_Price              542
# Delivery_Charges       267
# Coupon_Status            3
# GST                      4
# Date                   365
# Offline_Spend           11
# Online_Spend           365
# Month                   12
# dtype: int64

# %%
# change the date column into datetime formate

data["Date"] = pd.to_datetime(data["Date"])

# %% [markdown]
# <div style="background-color: BLACK; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: #b9f268; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">[......... DATA VISUALIZATION ..........]</h1>
# </div>

# %%
# tenure_month of the customer

order = data["Tenure_Months"].value_counts().iloc[:20].index

plt.figure(figsize=(10,4))       
sns.countplot(x = data["Tenure_Months"], data = data, order = order, palette = "hls")
plt.title("Customer and their tenure_Month")
plt.show()

# %% [markdown]
# # Result :
# ## **This  shows that more of  customer are stay  for ~40 ~ months in the platform for purchasing **

# %%
# sales in monthwise

count=data["Month"].value_counts().iloc[:12].index
plt.figure(figsize=(10,4))
sns.countplot(x = data["Month"], data = data, order = count, palette = "viridis")
plt.title("sales in a Month")
plt.show()

# %% [markdown]
# # Result :
# ## **It shows  AUGUST and JUNE  month have more sales and FEBUARY month has less sales **

# %%
# sales of product based on category

count=data["Product_Category"].value_counts().iloc[:20].index

plt.figure(figsize=(10,6))
sns.countplot(y=data["Product_Category"],order=count,data=data,palette="viridis")
plt.title("sales of product")
plt.show()

# %% [markdown]
# # Result :
# ## **This shows the more saled product_category : `Apparel` , `Nest-USA` , `Office`  products are mostly saled **

# %%
#customer based on Gender

values=data["Gender"].value_counts()

plt.pie(values, labels = ["Female","Male"], shadow = True, autopct = "%1.1f%%",explode=[.1,.1],colors=["#e32746","#27d0e3"])
plt.title("customer based on Gender")
plt.show()

# %% [markdown]
# # Result :
# ## **This chat show that there are more ~ Female ~  customers then Male customers **

# %%
#customer based on location

values=data["Location"].value_counts()

plt.pie(values, labels = values.index, shadow = True, autopct = "%1.1f%%",explode=[.1,.1,.1,.0,.0])
plt.title("customer based on location")
plt.show()

# %% [markdown]
# # Result :
# ##  **This chart shows that there are more customer from `chicago 34%` and `california` locations **

# %%
# Gst density
sns.set_style("darkgrid")
sns.kdeplot(data["GST"],color="red",fill=True)
plt.show()
sns.kdeplot(data["Quantity"],color="red",fill=True)
plt.show()

# %% [markdown]
# # Result:
# ## **The GST density show that there are most customer buy the product with 0.18% then 0.10% **
# ## **The second one show that most customer buys small Quanitity products.. **

# %%
year=data["Date"].dt.year.unique()
print( f"Year count  {year}\nNo of years is --------> {len(year)}")
# Out:
# Year count  [2019]
# No of years is --------> 1

# %% [markdown]
# # Result:
# ### **The DATASET shows the only one year of [ `2019`  ] sales  **

# %% [markdown]
# <div style="background-color: BLACK; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">TIME SERIES ANALYSIS</h1>
# </div>

# %%
# month wise sales online and offline

plt.figure(figsize=(10,4))

data.groupby("Month")["Offline_Spend"].agg("sum").plot()
plt.grid()
plt.title(" Offline sales ")
plt .xlabel("Month")
plt.ylabel("sales in lakh ")
plt.show()


plt.figure(figsize=(10,4))
data.groupby("Month")["Online_Spend"].agg("sum").plot(color="red")
plt.title(" Online sales ")
plt .xlabel("Month")
plt.ylabel("sales in lakh ")
plt.show()

# %% [markdown]
# # Result:
# ## **Both online and offline spending are  have same similar growth pattern ... the hike at month `AUGUST` and `DECEMBER` **

# %%
# to check the total product sales in a month

plt.figure(figsize=(10,4))
colors = plt.cm.viridis(np.linspace(0,0.8 , 12))
data.groupby("Month")["Product_Category"].agg("count").plot(kind="bar",color=colors)
plt.title(" product sales in a month ")
plt .xlabel("Month")
plt.ylabel("count of product sale")
plt.show()

# %% [markdown]
# # Result:
# ## **More number of products are sell in the month of ` AUGUST`  **

# %%
plt.figure(figsize=(10,4))
colors = plt.cm.viridis(np.linspace(0,0.9 , 5))
data.groupby("Location")["Product_Category"].agg("count").plot(kind="bar",color=colors)
plt.title(" product sales in a month ")
plt .xlabel("Location")
plt.ylabel("count of product sale in a location")
plt.show()

# %% [markdown]
# # Result:
# ## **More product are sell in the Location of `chicago` (>17500), `california`(>15000) products **

# %%
# top 5 category by Online_Spend

# create data frame call category
category = data.groupby("Product_Category")["Online_Spend"].sum().reset_index().sort_values(by = "Online_Spend", ascending = False).head(5)


plt.figure(figsize = (10,4))
sns.lineplot(x = "Product_Category", y = "Online_Spend", data = category, marker = 'o')
plt.show()

# top 5 category by Offline_Spend 

# create data frame call category
category = data.groupby("Product_Category")["Offline_Spend"].sum().reset_index().sort_values(by = "Offline_Spend", ascending = False).head(5)


plt.figure(figsize = (10,4))
sns.lineplot(x = "Product_Category", y = "Offline_Spend", data = category, marker = 'o',color="green")
plt.show()

# %% [markdown]
# # Result:
# ## **The offline spending and online spending is more in `Apparel ,neat-usa` products **

# %% [markdown]
# <div style="background-color: BLACK; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">🛑      Model building       🛑</h1>
# </div>

# %%
# Select only numeric columns
numeric_columns = data.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix for numeric variables
numeric_correlation_matrix = numeric_columns.corr()

# Plot the heatmap for numeric variables
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Numeric Correlation Matrix')
plt.show()

# %%
# import the nessceary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder,MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb

# %%
# Split the x and y value

x=data[["Avg_Price","Offline_Spend","Online_Spend","Quantity"]]                   
y= data["GST"]

# %%
# split the x and y train and test data 

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=43)

# %%
# scaling the data

feature  =  StandardScaler()

feature_data = feature.fit_transform(x_train)  # fit and transform  the data

feature_test =  feature.transform(x_test)

# %%
# Initialize the models 

model_tree = DecisionTreeRegressor(criterion="poisson",random_state=6,max_depth=10,ccp_alpha=0.0)

model_xgb = xgb.XGBRegressor( learning_rate = 0.9,
                max_depth = 75, alpha = 1, n_estimators = 10)

# %%
# fit the train data into the model

model_tree.fit(feature_data,y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=10, random_state=6)

# %%
# fit the train data into the model

model_xgb.fit(feature_data,y_train)
# Out:
# XGBRegressor(alpha=1, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.9, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=75, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=10, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# make the prediction in the train dataset

tree_train_score = model_tree.predict(feature_data)

XGB_train_score = model_xgb.predict(feature_data)

# %%
# make the prediction based in test data

tree_test_score = model_tree.predict(feature_test)

XGB_test_score = model_xgb.predict(feature_test)

# %%
# import the accuracy of the model
from sklearn import metrics

#  -------------------  R2 score ----------------

score_tree= metrics.r2_score(y_train, tree_train_score)              # train scores
score_XGB= metrics.r2_score(y_train, XGB_train_score)

score_tree_test = metrics.r2_score(y_test, tree_test_score)          # test scores
score_XGB_test = metrics.r2_score(y_test, XGB_test_score)

# %%
#  ----------------- Mean absolute error ------------

mean_score_tree  =  metrics.mean_absolute_error(y_train,tree_train_score)         # train data
mean_score_XGB  =  metrics.mean_absolute_error(y_train,XGB_train_score)


mean_score_tree_test = metrics.mean_absolute_error(y_test,tree_test_score)        # test data
mean_score_XGB_test = metrics.mean_absolute_error(y_test,XGB_test_score)

# %%
print(f"---- R2score ----\nD.Tree   {score_tree}\nXGB      {score_XGB}\n")

print(f"-----R2score ----\nD.tree  {score_tree_test}\nXGB      {score_XGB_test}")
# Out:
# ---- R2score ----
# D.Tree   0.6594920183460655
# XGB      0.6677814781226221
#
# -----R2score ----
# D.tree  0.634157093978899
# XGB      0.6344682220543986

# %%
print(f" Mean Absolute Error \n\nD.TREE :   {mean_score_tree}\nXGB  :     {mean_score_XGB}\n")

print(f" Mean Absolute Error \n\nD.TREE :   {mean_score_tree_test}\nXGB  :    {mean_score_XGB_test}")
# Out:
#  Mean Absolute Error
#
# D.TREE :   0.013997838929520537
# XGB  :     0.014733580313979469
#
#  Mean Absolute Error
#
# D.TREE :   0.014670295097174204
# XGB  :    0.015583567896659406

# %% [markdown]
# <div style="background-color: #9e030b; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">🛑      THANKS      🛑</h1
# </div>
